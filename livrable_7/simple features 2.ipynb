# %% [markdown]
# https://www.kaggle.com/code/jsaguiar/lightgbm-with-simple-features/script

# %%
#HOME CREDIT DEFAULT RISK COMPETITION
# Most features are created by applying min, max, mean, sum and var functions to grouped tables. 
# Little feature selection is done and overfitting might be a problem since many features are related.
# The following key ideas were used:
# - Divide or subtract important features to get rates (like annuity and income)
# - In Bureau Data: create specific features for Active credits and Closed credits
# - In Previous Applications: create specific features for Approved and Refused applications
# - Modularity: one function for each table (except bureau_balance and application_test)
# - One-hot encoding for categorical features
# All tables are joined with the application DF using the SK_ID_CURR key (except bureau_balance).
# You can use LightGBM with KFold or Stratified KFold.

# Update 16/06/2018:
# - Added Payment Rate feature
# - Removed index from features
# - Use standard KFold CV (not stratified)

import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('./data/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('./data/application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']
    
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    del test_df
    gc.collect()
    return df

# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('./data/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('./data/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
    
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# Preprocess previous_applications.csv
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('./data/previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# Preprocess POS_CASH_balance.csv
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv('./data/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg
    
# Preprocess installments_payments.csv
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv('./data/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('./data/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# LightGBM GBDT with KFold or Stratified KFold
# Parameters from Tilii kernel: https://www.kaggle.com/tilii7/olivier-lightgbm-parameters-by-bayesian-opt/code
def kfold_lightgbm(df, num_folds, stratified = False, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMClassifier(
            nthread=4,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=34,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.041545473,
            reg_lambda=0.0735294,
            min_split_gain=0.0222415,
            min_child_weight=39.3259775,
            silent=-1,
            verbose=-1, )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 200, early_stopping_rounds= 200)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

    print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        test_df['TARGET'] = sub_preds
        test_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    display_importances(feature_importance_df)
    return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances01.png')


def main(debug = False):
    num_rows = 10000 if debug else None
    df = application_train_test(num_rows)
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')
        del bureau
        gc.collect()
    with timer("Process previous_applications"):
        prev = previous_applications(num_rows)
        print("Previous applications df shape:", prev.shape)
        df = df.join(prev, how='left', on='SK_ID_CURR')
        del prev
        gc.collect()
    with timer("Process POS-CASH balance"):
        pos = pos_cash(num_rows)
        print("Pos-cash balance df shape:", pos.shape)
        df = df.join(pos, how='left', on='SK_ID_CURR')
        del pos
        gc.collect()
    with timer("Process installments payments"):
        ins = installments_payments(num_rows)
        print("Installments payments df shape:", ins.shape)
        df = df.join(ins, how='left', on='SK_ID_CURR')
        del ins
        gc.collect()
    with timer("Process credit card balance"):
        cc = credit_card_balance(num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
        del cc
        gc.collect()
    return df
    #with timer("Run LightGBM with kfold"):
    #    feat_importance = kfold_lightgbm(df, num_folds= 10, stratified= False, debug= debug)

if __name__ == "__main__":
    submission_file_name = "submission_kernel02.csv"
    with timer("Full model run"):
        df = main()
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 116)
# Process bureau and bureau_balance - done in 46s
# Previous applications df shape: (338857, 249)
# Process previous_applications - done in 53s
# Pos-cash balance df shape: (337252, 18)
# Process POS-CASH balance - done in 30s
# Installments payments df shape: (339587, 26)
# Process installments payments - done in 77s
# Credit card balance df shape: (103558, 141)
# Process credit card balance - done in 47s
# Full model run - done in 269s

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356251 entries, 0 to 356254
# Data columns (total 798 columns):
#  #    Column                                                                 Non-Null Count   Dtype
# ---   ------                                                                 --------------   -----
#  0    index                                                                  356251 non-null  int64
#  1    SK_ID_CURR                                                             356251 non-null  int64
#  2    TARGET                                                                 307507 non-null  float64
#  3    CODE_GENDER                                                            356251 non-null  int64
#  4    FLAG_OWN_CAR                                                           356251 non-null  int64
#  5    FLAG_OWN_REALTY                                                        356251 non-null  int64
#  6    CNT_CHILDREN                                                           356251 non-null  int64
#  7    AMT_INCOME_TOTAL                                                       356251 non-null  float64
#  8    AMT_CREDIT                                                             356251 non-null  float64
#  9    AMT_ANNUITY                                                            356215 non-null  float64
#  10   AMT_GOODS_PRICE                                                        355973 non-null  float64
#  11   REGION_POPULATION_RELATIVE                                             356251 non-null  float64
#  12   DAYS_BIRTH                                                             356251 non-null  int64
#  13   DAYS_EMPLOYED                                                          291603 non-null  float64
#  14   DAYS_REGISTRATION                                                      356251 non-null  float64
#  15   DAYS_ID_PUBLISH                                                        356251 non-null  int64
#  16   OWN_CAR_AGE                                                            121012 non-null  float64
#  17   FLAG_MOBIL                                                             356251 non-null  int64
#  18   FLAG_EMP_PHONE                                                         356251 non-null  int64
#  19   FLAG_WORK_PHONE                                                        356251 non-null  int64
#  20   FLAG_CONT_MOBILE                                                       356251 non-null  int64
#  21   FLAG_PHONE                                                             356251 non-null  int64
#  22   FLAG_EMAIL                                                             356251 non-null  int64
#  23   CNT_FAM_MEMBERS                                                        356249 non-null  float64
#  24   REGION_RATING_CLIENT                                                   356251 non-null  int64
#  25   REGION_RATING_CLIENT_W_CITY                                            356251 non-null  int64
#  26   HOUR_APPR_PROCESS_START                                                356251 non-null  int64
#  27   REG_REGION_NOT_LIVE_REGION                                             356251 non-null  int64
#  28   REG_REGION_NOT_WORK_REGION                                             356251 non-null  int64
#  29   LIVE_REGION_NOT_WORK_REGION                                            356251 non-null  int64
#  30   REG_CITY_NOT_LIVE_CITY                                                 356251 non-null  int64
#  31   REG_CITY_NOT_WORK_CITY                                                 356251 non-null  int64
#  32   LIVE_CITY_NOT_WORK_CITY                                                356251 non-null  int64
#  33   EXT_SOURCE_1                                                           162343 non-null  float64
#  34   EXT_SOURCE_2                                                           355583 non-null  float64
#  35   EXT_SOURCE_3                                                           286618 non-null  float64
#  36   APARTMENTS_AVG                                                         176304 non-null  float64
#  37   BASEMENTAREA_AVG                                                       148668 non-null  float64
#  38   YEARS_BEGINEXPLUATATION_AVG                                            183389 non-null  float64
#  39   YEARS_BUILD_AVG                                                        119947 non-null  float64
#  40   COMMONAREA_AVG                                                         107894 non-null  float64
#  41   ELEVATORS_AVG                                                          167172 non-null  float64
#  42   ENTRANCES_AVG                                                          177845 non-null  float64
#  43   FLOORSMAX_AVG                                                          179911 non-null  float64
#  44   FLOORSMIN_AVG                                                          115145 non-null  float64
#  45   LANDAREA_AVG                                                           145409 non-null  float64
#  46   LIVINGAPARTMENTS_AVG                                                   113274 non-null  float64
#  47   LIVINGAREA_AVG                                                         178350 non-null  float64
#  48   NONLIVINGAPARTMENTS_AVG                                                109392 non-null  float64
#  49   NONLIVINGAREA_AVG                                                      160487 non-null  float64
#  50   APARTMENTS_MODE                                                        176304 non-null  float64
#  51   BASEMENTAREA_MODE                                                      148668 non-null  float64
#  52   YEARS_BEGINEXPLUATATION_MODE                                           183389 non-null  float64
#  53   YEARS_BUILD_MODE                                                       119947 non-null  float64
#  54   COMMONAREA_MODE                                                        107894 non-null  float64
#  55   ELEVATORS_MODE                                                         167172 non-null  float64
#  56   ENTRANCES_MODE                                                         177845 non-null  float64
#  57   FLOORSMAX_MODE                                                         179911 non-null  float64
#  58   FLOORSMIN_MODE                                                         115145 non-null  float64
#  59   LANDAREA_MODE                                                          145409 non-null  float64
#  60   LIVINGAPARTMENTS_MODE                                                  113274 non-null  float64
#  61   LIVINGAREA_MODE                                                        178350 non-null  float64
#  62   NONLIVINGAPARTMENTS_MODE                                               109392 non-null  float64
#  63   NONLIVINGAREA_MODE                                                     160487 non-null  float64
#  64   APARTMENTS_MEDI                                                        176304 non-null  float64
#  65   BASEMENTAREA_MEDI                                                      148668 non-null  float64
#  66   YEARS_BEGINEXPLUATATION_MEDI                                           183389 non-null  float64
#  67   YEARS_BUILD_MEDI                                                       119947 non-null  float64
#  68   COMMONAREA_MEDI                                                        107894 non-null  float64
#  69   ELEVATORS_MEDI                                                         167172 non-null  float64
#  70   ENTRANCES_MEDI                                                         177845 non-null  float64
#  71   FLOORSMAX_MEDI                                                         179911 non-null  float64
#  72   FLOORSMIN_MEDI                                                         115145 non-null  float64
#  73   LANDAREA_MEDI                                                          145409 non-null  float64
#  74   LIVINGAPARTMENTS_MEDI                                                  113274 non-null  float64
#  75   LIVINGAREA_MEDI                                                        178350 non-null  float64
#  76   NONLIVINGAPARTMENTS_MEDI                                               109392 non-null  float64
#  77   NONLIVINGAREA_MEDI                                                     160487 non-null  float64
#  78   TOTALAREA_MODE                                                         185197 non-null  float64
#  79   OBS_30_CNT_SOCIAL_CIRCLE                                               355201 non-null  float64
#  80   DEF_30_CNT_SOCIAL_CIRCLE                                               355201 non-null  float64
#  81   OBS_60_CNT_SOCIAL_CIRCLE                                               355201 non-null  float64
#  82   DEF_60_CNT_SOCIAL_CIRCLE                                               355201 non-null  float64
#  83   DAYS_LAST_PHONE_CHANGE                                                 356250 non-null  float64
#  84   FLAG_DOCUMENT_2                                                        356251 non-null  int64
#  85   FLAG_DOCUMENT_3                                                        356251 non-null  int64
#  86   FLAG_DOCUMENT_4                                                        356251 non-null  int64
#  87   FLAG_DOCUMENT_5                                                        356251 non-null  int64
#  88   FLAG_DOCUMENT_6                                                        356251 non-null  int64
#  89   FLAG_DOCUMENT_7                                                        356251 non-null  int64
#  90   FLAG_DOCUMENT_8                                                        356251 non-null  int64
#  91   FLAG_DOCUMENT_9                                                        356251 non-null  int64
#  92   FLAG_DOCUMENT_10                                                       356251 non-null  int64
#  93   FLAG_DOCUMENT_11                                                       356251 non-null  int64
#  94   FLAG_DOCUMENT_12                                                       356251 non-null  int64
#  95   FLAG_DOCUMENT_13                                                       356251 non-null  int64
#  96   FLAG_DOCUMENT_14                                                       356251 non-null  int64
#  97   FLAG_DOCUMENT_15                                                       356251 non-null  int64
#  98   FLAG_DOCUMENT_16                                                       356251 non-null  int64
#  99   FLAG_DOCUMENT_17                                                       356251 non-null  int64
#  100  FLAG_DOCUMENT_18                                                       356251 non-null  int64
#  101  FLAG_DOCUMENT_19                                                       356251 non-null  int64
#  102  FLAG_DOCUMENT_20                                                       356251 non-null  int64
#  103  FLAG_DOCUMENT_21                                                       356251 non-null  int64
#  104  AMT_REQ_CREDIT_BUREAU_HOUR                                             308683 non-null  float64
#  105  AMT_REQ_CREDIT_BUREAU_DAY                                              308683 non-null  float64
#  106  AMT_REQ_CREDIT_BUREAU_WEEK                                             308683 non-null  float64
#  107  AMT_REQ_CREDIT_BUREAU_MON                                              308683 non-null  float64
#  108  AMT_REQ_CREDIT_BUREAU_QRT                                              308683 non-null  float64
#  109  AMT_REQ_CREDIT_BUREAU_YEAR                                             308683 non-null  float64
#  110  NAME_CONTRACT_TYPE_Cash loans                                          356251 non-null  uint8
#  111  NAME_CONTRACT_TYPE_Revolving loans                                     356251 non-null  uint8
#  112  NAME_TYPE_SUITE_Children                                               356251 non-null  uint8
#  113  NAME_TYPE_SUITE_Family                                                 356251 non-null  uint8
#  114  NAME_TYPE_SUITE_Group of people                                        356251 non-null  uint8
#  115  NAME_TYPE_SUITE_Other_A                                                356251 non-null  uint8
#  116  NAME_TYPE_SUITE_Other_B                                                356251 non-null  uint8
#  117  NAME_TYPE_SUITE_Spouse, partner                                        356251 non-null  uint8
#  118  NAME_TYPE_SUITE_Unaccompanied                                          356251 non-null  uint8
#  119  NAME_INCOME_TYPE_Businessman                                           356251 non-null  uint8
#  120  NAME_INCOME_TYPE_Commercial associate                                  356251 non-null  uint8
#  121  NAME_INCOME_TYPE_Maternity leave                                       356251 non-null  uint8
#  122  NAME_INCOME_TYPE_Pensioner                                             356251 non-null  uint8
#  123  NAME_INCOME_TYPE_State servant                                         356251 non-null  uint8
#  124  NAME_INCOME_TYPE_Student                                               356251 non-null  uint8
#  125  NAME_INCOME_TYPE_Unemployed                                            356251 non-null  uint8
#  126  NAME_INCOME_TYPE_Working                                               356251 non-null  uint8
#  127  NAME_EDUCATION_TYPE_Academic degree                                    356251 non-null  uint8
#  128  NAME_EDUCATION_TYPE_Higher education                                   356251 non-null  uint8
#  129  NAME_EDUCATION_TYPE_Incomplete higher                                  356251 non-null  uint8
#  130  NAME_EDUCATION_TYPE_Lower secondary                                    356251 non-null  uint8
#  131  NAME_EDUCATION_TYPE_Secondary / secondary special                      356251 non-null  uint8
#  132  NAME_FAMILY_STATUS_Civil marriage                                      356251 non-null  uint8
#  133  NAME_FAMILY_STATUS_Married                                             356251 non-null  uint8
#  134  NAME_FAMILY_STATUS_Separated                                           356251 non-null  uint8
#  135  NAME_FAMILY_STATUS_Single / not married                                356251 non-null  uint8
#  136  NAME_FAMILY_STATUS_Unknown                                             356251 non-null  uint8
#  137  NAME_FAMILY_STATUS_Widow                                               356251 non-null  uint8
#  138  NAME_HOUSING_TYPE_Co-op apartment                                      356251 non-null  uint8
#  139  NAME_HOUSING_TYPE_House / apartment                                    356251 non-null  uint8
#  140  NAME_HOUSING_TYPE_Municipal apartment                                  356251 non-null  uint8
#  141  NAME_HOUSING_TYPE_Office apartment                                     356251 non-null  uint8
#  142  NAME_HOUSING_TYPE_Rented apartment                                     356251 non-null  uint8
#  143  NAME_HOUSING_TYPE_With parents                                         356251 non-null  uint8
#  144  OCCUPATION_TYPE_Accountants                                            356251 non-null  uint8
#  145  OCCUPATION_TYPE_Cleaning staff                                         356251 non-null  uint8
#  146  OCCUPATION_TYPE_Cooking staff                                          356251 non-null  uint8
#  147  OCCUPATION_TYPE_Core staff                                             356251 non-null  uint8
#  148  OCCUPATION_TYPE_Drivers                                                356251 non-null  uint8
#  149  OCCUPATION_TYPE_HR staff                                               356251 non-null  uint8
#  150  OCCUPATION_TYPE_High skill tech staff                                  356251 non-null  uint8
#  151  OCCUPATION_TYPE_IT staff                                               356251 non-null  uint8
#  152  OCCUPATION_TYPE_Laborers                                               356251 non-null  uint8
#  153  OCCUPATION_TYPE_Low-skill Laborers                                     356251 non-null  uint8
#  154  OCCUPATION_TYPE_Managers                                               356251 non-null  uint8
#  155  OCCUPATION_TYPE_Medicine staff                                         356251 non-null  uint8
#  156  OCCUPATION_TYPE_Private service staff                                  356251 non-null  uint8
#  157  OCCUPATION_TYPE_Realty agents                                          356251 non-null  uint8
#  158  OCCUPATION_TYPE_Sales staff                                            356251 non-null  uint8
#  159  OCCUPATION_TYPE_Secretaries                                            356251 non-null  uint8
#  160  OCCUPATION_TYPE_Security staff                                         356251 non-null  uint8
#  161  OCCUPATION_TYPE_Waiters/barmen staff                                   356251 non-null  uint8
#  162  WEEKDAY_APPR_PROCESS_START_FRIDAY                                      356251 non-null  uint8
#  163  WEEKDAY_APPR_PROCESS_START_MONDAY                                      356251 non-null  uint8
#  164  WEEKDAY_APPR_PROCESS_START_SATURDAY                                    356251 non-null  uint8
#  165  WEEKDAY_APPR_PROCESS_START_SUNDAY                                      356251 non-null  uint8
#  166  WEEKDAY_APPR_PROCESS_START_THURSDAY                                    356251 non-null  uint8
#  167  WEEKDAY_APPR_PROCESS_START_TUESDAY                                     356251 non-null  uint8
#  168  WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                   356251 non-null  uint8
#  169  ORGANIZATION_TYPE_Advertising                                          356251 non-null  uint8
#  170  ORGANIZATION_TYPE_Agriculture                                          356251 non-null  uint8
#  171  ORGANIZATION_TYPE_Bank                                                 356251 non-null  uint8
#  172  ORGANIZATION_TYPE_Business Entity Type 1                               356251 non-null  uint8
#  173  ORGANIZATION_TYPE_Business Entity Type 2                               356251 non-null  uint8
#  174  ORGANIZATION_TYPE_Business Entity Type 3                               356251 non-null  uint8
#  175  ORGANIZATION_TYPE_Cleaning                                             356251 non-null  uint8
#  176  ORGANIZATION_TYPE_Construction                                         356251 non-null  uint8
#  177  ORGANIZATION_TYPE_Culture                                              356251 non-null  uint8
#  178  ORGANIZATION_TYPE_Electricity                                          356251 non-null  uint8
#  179  ORGANIZATION_TYPE_Emergency                                            356251 non-null  uint8
#  180  ORGANIZATION_TYPE_Government                                           356251 non-null  uint8
#  181  ORGANIZATION_TYPE_Hotel                                                356251 non-null  uint8
#  182  ORGANIZATION_TYPE_Housing                                              356251 non-null  uint8
#  183  ORGANIZATION_TYPE_Industry: type 1                                     356251 non-null  uint8
#  184  ORGANIZATION_TYPE_Industry: type 10                                    356251 non-null  uint8
#  185  ORGANIZATION_TYPE_Industry: type 11                                    356251 non-null  uint8
#  186  ORGANIZATION_TYPE_Industry: type 12                                    356251 non-null  uint8
#  187  ORGANIZATION_TYPE_Industry: type 13                                    356251 non-null  uint8
#  188  ORGANIZATION_TYPE_Industry: type 2                                     356251 non-null  uint8
#  189  ORGANIZATION_TYPE_Industry: type 3                                     356251 non-null  uint8
#  190  ORGANIZATION_TYPE_Industry: type 4                                     356251 non-null  uint8
#  191  ORGANIZATION_TYPE_Industry: type 5                                     356251 non-null  uint8
#  192  ORGANIZATION_TYPE_Industry: type 6                                     356251 non-null  uint8
#  193  ORGANIZATION_TYPE_Industry: type 7                                     356251 non-null  uint8
#  194  ORGANIZATION_TYPE_Industry: type 8                                     356251 non-null  uint8
#  195  ORGANIZATION_TYPE_Industry: type 9                                     356251 non-null  uint8
#  196  ORGANIZATION_TYPE_Insurance                                            356251 non-null  uint8
#  197  ORGANIZATION_TYPE_Kindergarten                                         356251 non-null  uint8
#  198  ORGANIZATION_TYPE_Legal Services                                       356251 non-null  uint8
#  199  ORGANIZATION_TYPE_Medicine                                             356251 non-null  uint8
#  200  ORGANIZATION_TYPE_Military                                             356251 non-null  uint8
#  201  ORGANIZATION_TYPE_Mobile                                               356251 non-null  uint8
#  202  ORGANIZATION_TYPE_Other                                                356251 non-null  uint8
#  203  ORGANIZATION_TYPE_Police                                               356251 non-null  uint8
#  204  ORGANIZATION_TYPE_Postal                                               356251 non-null  uint8
#  205  ORGANIZATION_TYPE_Realtor                                              356251 non-null  uint8
#  206  ORGANIZATION_TYPE_Religion                                             356251 non-null  uint8
#  207  ORGANIZATION_TYPE_Restaurant                                           356251 non-null  uint8
#  208  ORGANIZATION_TYPE_School                                               356251 non-null  uint8
#  209  ORGANIZATION_TYPE_Security                                             356251 non-null  uint8
#  210  ORGANIZATION_TYPE_Security Ministries                                  356251 non-null  uint8
#  211  ORGANIZATION_TYPE_Self-employed                                        356251 non-null  uint8
#  212  ORGANIZATION_TYPE_Services                                             356251 non-null  uint8
#  213  ORGANIZATION_TYPE_Telecom                                              356251 non-null  uint8
#  214  ORGANIZATION_TYPE_Trade: type 1                                        356251 non-null  uint8
#  215  ORGANIZATION_TYPE_Trade: type 2                                        356251 non-null  uint8
#  216  ORGANIZATION_TYPE_Trade: type 3                                        356251 non-null  uint8
#  217  ORGANIZATION_TYPE_Trade: type 4                                        356251 non-null  uint8
#  218  ORGANIZATION_TYPE_Trade: type 5                                        356251 non-null  uint8
#  219  ORGANIZATION_TYPE_Trade: type 6                                        356251 non-null  uint8
#  220  ORGANIZATION_TYPE_Trade: type 7                                        356251 non-null  uint8
#  221  ORGANIZATION_TYPE_Transport: type 1                                    356251 non-null  uint8
#  222  ORGANIZATION_TYPE_Transport: type 2                                    356251 non-null  uint8
#  223  ORGANIZATION_TYPE_Transport: type 3                                    356251 non-null  uint8
#  224  ORGANIZATION_TYPE_Transport: type 4                                    356251 non-null  uint8
#  225  ORGANIZATION_TYPE_University                                           356251 non-null  uint8
#  226  ORGANIZATION_TYPE_XNA                                                  356251 non-null  uint8
#  227  FONDKAPREMONT_MODE_not specified                                       356251 non-null  uint8
#  228  FONDKAPREMONT_MODE_org spec account                                    356251 non-null  uint8
#  229  FONDKAPREMONT_MODE_reg oper account                                    356251 non-null  uint8
#  230  FONDKAPREMONT_MODE_reg oper spec account                               356251 non-null  uint8
#  231  HOUSETYPE_MODE_block of flats                                          356251 non-null  uint8
#  232  HOUSETYPE_MODE_specific housing                                        356251 non-null  uint8
#  233  HOUSETYPE_MODE_terraced house                                          356251 non-null  uint8
#  234  WALLSMATERIAL_MODE_Block                                               356251 non-null  uint8
#  235  WALLSMATERIAL_MODE_Mixed                                               356251 non-null  uint8
#  236  WALLSMATERIAL_MODE_Monolithic                                          356251 non-null  uint8
#  237  WALLSMATERIAL_MODE_Others                                              356251 non-null  uint8
#  238  WALLSMATERIAL_MODE_Panel                                               356251 non-null  uint8
#  239  WALLSMATERIAL_MODE_Stone, brick                                        356251 non-null  uint8
#  240  WALLSMATERIAL_MODE_Wooden                                              356251 non-null  uint8
#  241  EMERGENCYSTATE_MODE_No                                                 356251 non-null  uint8
#  242  EMERGENCYSTATE_MODE_Yes                                                356251 non-null  uint8
#  243  DAYS_EMPLOYED_PERC                                                     291603 non-null  float64
#  244  INCOME_CREDIT_PERC                                                     356251 non-null  float64
#  245  INCOME_PER_PERSON                                                      356249 non-null  float64
#  246  ANNUITY_INCOME_PERC                                                    356215 non-null  float64
#  247  PAYMENT_RATE                                                           356215 non-null  float64
#  248  BURO_DAYS_CREDIT_MIN                                                   305807 non-null  float64
#  249  BURO_DAYS_CREDIT_MAX                                                   305807 non-null  float64
#  250  BURO_DAYS_CREDIT_MEAN                                                  305807 non-null  float64
#  251  BURO_DAYS_CREDIT_VAR                                                   264287 non-null  float64
#  252  BURO_DAYS_CREDIT_ENDDATE_MIN                                           303222 non-null  float64
#  253  BURO_DAYS_CREDIT_ENDDATE_MAX                                           303222 non-null  float64
#  254  BURO_DAYS_CREDIT_ENDDATE_MEAN                                          303222 non-null  float64
#  255  BURO_DAYS_CREDIT_UPDATE_MEAN                                           305807 non-null  float64
#  256  BURO_CREDIT_DAY_OVERDUE_MAX                                            305807 non-null  float64
#  257  BURO_CREDIT_DAY_OVERDUE_MEAN                                           305807 non-null  float64
#  258  BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                       212967 non-null  float64
#  259  BURO_AMT_CREDIT_SUM_MAX                                                305805 non-null  float64
#  260  BURO_AMT_CREDIT_SUM_MEAN                                               305805 non-null  float64
#  261  BURO_AMT_CREDIT_SUM_SUM                                                305807 non-null  float64
#  262  BURO_AMT_CREDIT_SUM_DEBT_MAX                                           297435 non-null  float64
#  263  BURO_AMT_CREDIT_SUM_DEBT_MEAN                                          297435 non-null  float64
#  264  BURO_AMT_CREDIT_SUM_DEBT_SUM                                           305807 non-null  float64
#  265  BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                       305807 non-null  float64
#  266  BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                         280499 non-null  float64
#  267  BURO_AMT_CREDIT_SUM_LIMIT_SUM                                          305807 non-null  float64
#  268  BURO_AMT_ANNUITY_MAX                                                   118224 non-null  float64
#  269  BURO_AMT_ANNUITY_MEAN                                                  118224 non-null  float64
#  270  BURO_CNT_CREDIT_PROLONG_SUM                                            305807 non-null  float64
#  271  BURO_MONTHS_BALANCE_MIN_MIN                                            134542 non-null  float64
#  272  BURO_MONTHS_BALANCE_MAX_MAX                                            134542 non-null  float64
#  273  BURO_MONTHS_BALANCE_SIZE_MEAN                                          134542 non-null  float64
#  274  BURO_MONTHS_BALANCE_SIZE_SUM                                           305807 non-null  float64
#  275  BURO_CREDIT_ACTIVE_Active_MEAN                                         305807 non-null  float64
#  276  BURO_CREDIT_ACTIVE_Bad debt_MEAN                                       305807 non-null  float64
#  277  BURO_CREDIT_ACTIVE_Closed_MEAN                                         305807 non-null  float64
#  278  BURO_CREDIT_ACTIVE_Sold_MEAN                                           305807 non-null  float64
#  279  BURO_CREDIT_ACTIVE_nan_MEAN                                            305807 non-null  float64
#  280  BURO_CREDIT_CURRENCY_currency 1_MEAN                                   305807 non-null  float64
#  281  BURO_CREDIT_CURRENCY_currency 2_MEAN                                   305807 non-null  float64
#  282  BURO_CREDIT_CURRENCY_currency 3_MEAN                                   305807 non-null  float64
#  283  BURO_CREDIT_CURRENCY_currency 4_MEAN                                   305807 non-null  float64
#  284  BURO_CREDIT_CURRENCY_nan_MEAN                                          305807 non-null  float64
#  285  BURO_CREDIT_TYPE_Another type of loan_MEAN                             305807 non-null  float64
#  286  BURO_CREDIT_TYPE_Car loan_MEAN                                         305807 non-null  float64
#  287  BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                        305807 non-null  float64
#  288  BURO_CREDIT_TYPE_Consumer credit_MEAN                                  305807 non-null  float64
#  289  BURO_CREDIT_TYPE_Credit card_MEAN                                      305807 non-null  float64
#  290  BURO_CREDIT_TYPE_Interbank credit_MEAN                                 305807 non-null  float64
#  291  BURO_CREDIT_TYPE_Loan for business development_MEAN                    305807 non-null  float64
#  292  BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN     305807 non-null  float64
#  293  BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN               305807 non-null  float64
#  294  BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN           305807 non-null  float64
#  295  BURO_CREDIT_TYPE_Microloan_MEAN                                        305807 non-null  float64
#  296  BURO_CREDIT_TYPE_Mobile operator loan_MEAN                             305807 non-null  float64
#  297  BURO_CREDIT_TYPE_Mortgage_MEAN                                         305807 non-null  float64
#  298  BURO_CREDIT_TYPE_Real estate loan_MEAN                                 305807 non-null  float64
#  299  BURO_CREDIT_TYPE_Unknown type of loan_MEAN                             305807 non-null  float64
#  300  BURO_CREDIT_TYPE_nan_MEAN                                              305807 non-null  float64
#  301  BURO_STATUS_0_MEAN_MEAN                                                134542 non-null  float64
#  302  BURO_STATUS_1_MEAN_MEAN                                                134542 non-null  float64
#  303  BURO_STATUS_2_MEAN_MEAN                                                134542 non-null  float64
#  304  BURO_STATUS_3_MEAN_MEAN                                                134542 non-null  float64
#  305  BURO_STATUS_4_MEAN_MEAN                                                134542 non-null  float64
#  306  BURO_STATUS_5_MEAN_MEAN                                                134542 non-null  float64
#  307  BURO_STATUS_C_MEAN_MEAN                                                134542 non-null  float64
#  308  BURO_STATUS_X_MEAN_MEAN                                                134542 non-null  float64
#  309  BURO_STATUS_nan_MEAN_MEAN                                              134542 non-null  float64
#  310  ACTIVE_DAYS_CREDIT_MIN                                                 251811 non-null  float64
#  311  ACTIVE_DAYS_CREDIT_MAX                                                 251811 non-null  float64
#  312  ACTIVE_DAYS_CREDIT_MEAN                                                251811 non-null  float64
#  313  ACTIVE_DAYS_CREDIT_VAR                                                 166323 non-null  float64
#  314  ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                         241342 non-null  float64
#  315  ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                         241342 non-null  float64
#  316  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                        241342 non-null  float64
#  317  ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                         251811 non-null  float64
#  318  ACTIVE_CREDIT_DAY_OVERDUE_MAX                                          251811 non-null  float64
#  319  ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                         251811 non-null  float64
#  320  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                     132997 non-null  float64
#  321  ACTIVE_AMT_CREDIT_SUM_MAX                                              251808 non-null  float64
#  322  ACTIVE_AMT_CREDIT_SUM_MEAN                                             251808 non-null  float64
#  323  ACTIVE_AMT_CREDIT_SUM_SUM                                              251811 non-null  float64
#  324  ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                         239860 non-null  float64
#  325  ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                        239860 non-null  float64
#  326  ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                         251811 non-null  float64
#  327  ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                     251811 non-null  float64
#  328  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                       218100 non-null  float64
#  329  ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                        251811 non-null  float64
#  330  ACTIVE_AMT_ANNUITY_MAX                                                 92726 non-null   float64
#  331  ACTIVE_AMT_ANNUITY_MEAN                                                92726 non-null   float64
#  332  ACTIVE_CNT_CREDIT_PROLONG_SUM                                          251811 non-null  float64
#  333  ACTIVE_MONTHS_BALANCE_MIN_MIN                                          111149 non-null  float64
#  334  ACTIVE_MONTHS_BALANCE_MAX_MAX                                          111149 non-null  float64
#  335  ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                        111149 non-null  float64
#  336  ACTIVE_MONTHS_BALANCE_SIZE_SUM                                         251811 non-null  float64
#  337  CLOSED_DAYS_CREDIT_MIN                                                 267921 non-null  float64
#  338  CLOSED_DAYS_CREDIT_MAX                                                 267921 non-null  float64
#  339  CLOSED_DAYS_CREDIT_MEAN                                                267921 non-null  float64
#  340  CLOSED_DAYS_CREDIT_VAR                                                 206226 non-null  float64
#  341  CLOSED_DAYS_CREDIT_ENDDATE_MIN                                         266168 non-null  float64
#  342  CLOSED_DAYS_CREDIT_ENDDATE_MAX                                         266168 non-null  float64
#  343  CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                        266168 non-null  float64
#  344  CLOSED_DAYS_CREDIT_UPDATE_MEAN                                         267921 non-null  float64
#  345  CLOSED_CREDIT_DAY_OVERDUE_MAX                                          267921 non-null  float64
#  346  CLOSED_CREDIT_DAY_OVERDUE_MEAN                                         267921 non-null  float64
#  347  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                     169896 non-null  float64
#  348  CLOSED_AMT_CREDIT_SUM_MAX                                              267921 non-null  float64
#  349  CLOSED_AMT_CREDIT_SUM_MEAN                                             267921 non-null  float64
#  350  CLOSED_AMT_CREDIT_SUM_SUM                                              267921 non-null  float64
#  351  CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                         254332 non-null  float64
#  352  CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                        254332 non-null  float64
#  353  CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                         267921 non-null  float64
#  354  CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                     267921 non-null  float64
#  355  CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                       229937 non-null  float64
#  356  CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                        267921 non-null  float64
#  357  CLOSED_AMT_ANNUITY_MAX                                                 95197 non-null   float64
#  358  CLOSED_AMT_ANNUITY_MEAN                                                95197 non-null   float64
#  359  CLOSED_CNT_CREDIT_PROLONG_SUM                                          267921 non-null  float64
#  360  CLOSED_MONTHS_BALANCE_MIN_MIN                                          118495 non-null  float64
#  361  CLOSED_MONTHS_BALANCE_MAX_MAX                                          118495 non-null  float64
#  362  CLOSED_MONTHS_BALANCE_SIZE_MEAN                                        118495 non-null  float64
#  363  CLOSED_MONTHS_BALANCE_SIZE_SUM                                         267921 non-null  float64
#  364  PREV_AMT_ANNUITY_MIN                                                   338373 non-null  float64
#  365  PREV_AMT_ANNUITY_MAX                                                   338373 non-null  float64
#  366  PREV_AMT_ANNUITY_MEAN                                                  338373 non-null  float64
#  367  PREV_AMT_APPLICATION_MIN                                               338853 non-null  float64
#  368  PREV_AMT_APPLICATION_MAX                                               338853 non-null  float64
#  369  PREV_AMT_APPLICATION_MEAN                                              338853 non-null  float64
#  370  PREV_AMT_CREDIT_MIN                                                    338853 non-null  float64
#  371  PREV_AMT_CREDIT_MAX                                                    338853 non-null  float64
#  372  PREV_AMT_CREDIT_MEAN                                                   338853 non-null  float64
#  373  PREV_APP_CREDIT_PERC_MIN                                               338601 non-null  float64
#  374  PREV_APP_CREDIT_PERC_MAX                                               338601 non-null  float64
#  375  PREV_APP_CREDIT_PERC_MEAN                                              338600 non-null  float64
#  376  PREV_APP_CREDIT_PERC_VAR                                               267817 non-null  float64
#  377  PREV_AMT_DOWN_PAYMENT_MIN                                              318749 non-null  float64
#  378  PREV_AMT_DOWN_PAYMENT_MAX                                              318749 non-null  float64
#  379  PREV_AMT_DOWN_PAYMENT_MEAN                                             318749 non-null  float64
#  380  PREV_AMT_GOODS_PRICE_MIN                                               337789 non-null  float64
#  381  PREV_AMT_GOODS_PRICE_MAX                                               337789 non-null  float64
#  382  PREV_AMT_GOODS_PRICE_MEAN                                              337789 non-null  float64
#  383  PREV_HOUR_APPR_PROCESS_START_MIN                                       338853 non-null  float64
#  384  PREV_HOUR_APPR_PROCESS_START_MAX                                       338853 non-null  float64
#  385  PREV_HOUR_APPR_PROCESS_START_MEAN                                      338853 non-null  float64
#  386  PREV_RATE_DOWN_PAYMENT_MIN                                             318749 non-null  float64
#  387  PREV_RATE_DOWN_PAYMENT_MAX                                             318749 non-null  float64
#  388  PREV_RATE_DOWN_PAYMENT_MEAN                                            318749 non-null  float64
#  389  PREV_DAYS_DECISION_MIN                                                 338853 non-null  float64
#  390  PREV_DAYS_DECISION_MAX                                                 338853 non-null  float64
#  391  PREV_DAYS_DECISION_MEAN                                                338853 non-null  float64
#  392  PREV_CNT_PAYMENT_MEAN                                                  338375 non-null  float64
#  393  PREV_CNT_PAYMENT_SUM                                                   338853 non-null  float64
#  394  PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                338853 non-null  float64
#  395  PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                            338853 non-null  float64
#  396  PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                           338853 non-null  float64
#  397  PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                       338853 non-null  float64
#  398  PREV_NAME_CONTRACT_TYPE_nan_MEAN                                       338853 non-null  float64
#  399  PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                            338853 non-null  float64
#  400  PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                            338853 non-null  float64
#  401  PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                          338853 non-null  float64
#  402  PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                            338853 non-null  float64
#  403  PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                          338853 non-null  float64
#  404  PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                           338853 non-null  float64
#  405  PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                         338853 non-null  float64
#  406  PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN                               338853 non-null  float64
#  407  PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN                                338853 non-null  float64
#  408  PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN                                338853 non-null  float64
#  409  PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN                              338853 non-null  float64
#  410  PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN          338853 non-null  float64
#  411  PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                  338853 non-null  float64
#  412  PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                       338853 non-null  float64
#  413  PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN          338853 non-null  float64
#  414  PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                         338853 non-null  float64
#  415  PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                      338853 non-null  float64
#  416  PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                     338853 non-null  float64
#  417  PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                           338853 non-null  float64
#  418  PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                             338853 non-null  float64
#  419  PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                     338853 non-null  float64
#  420  PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                             338853 non-null  float64
#  421  PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN           338853 non-null  float64
#  422  PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                 338853 non-null  float64
#  423  PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                               338853 non-null  float64
#  424  PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                              338853 non-null  float64
#  425  PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN              338853 non-null  float64
#  426  PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                 338853 non-null  float64
#  427  PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN               338853 non-null  float64
#  428  PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN      338853 non-null  float64
#  429  PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN              338853 non-null  float64
#  430  PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                               338853 non-null  float64
#  431  PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                          338853 non-null  float64
#  432  PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN              338853 non-null  float64
#  433  PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                   338853 non-null  float64
#  434  PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                   338853 non-null  float64
#  435  PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN                                   338853 non-null  float64
#  436  PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                338853 non-null  float64
#  437  PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                338853 non-null  float64
#  438  PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                 338853 non-null  float64
#  439  PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                            338853 non-null  float64
#  440  PREV_NAME_CONTRACT_STATUS_nan_MEAN                                     338853 non-null  float64
#  441  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                      338853 non-null  float64
#  442  PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN  338853 non-null  float64
#  443  PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                 338853 non-null  float64
#  444  PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                        338853 non-null  float64
#  445  PREV_NAME_PAYMENT_TYPE_nan_MEAN                                        338853 non-null  float64
#  446  PREV_CODE_REJECT_REASON_CLIENT_MEAN                                    338853 non-null  float64
#  447  PREV_CODE_REJECT_REASON_HC_MEAN                                        338853 non-null  float64
#  448  PREV_CODE_REJECT_REASON_LIMIT_MEAN                                     338853 non-null  float64
#  449  PREV_CODE_REJECT_REASON_SCO_MEAN                                       338853 non-null  float64
#  450  PREV_CODE_REJECT_REASON_SCOFR_MEAN                                     338853 non-null  float64
#  451  PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                    338853 non-null  float64
#  452  PREV_CODE_REJECT_REASON_VERIF_MEAN                                     338853 non-null  float64
#  453  PREV_CODE_REJECT_REASON_XAP_MEAN                                       338853 non-null  float64
#  454  PREV_CODE_REJECT_REASON_XNA_MEAN                                       338853 non-null  float64
#  455  PREV_CODE_REJECT_REASON_nan_MEAN                                       338853 non-null  float64
#  456  PREV_NAME_TYPE_SUITE_Children_MEAN                                     338853 non-null  float64
#  457  PREV_NAME_TYPE_SUITE_Family_MEAN                                       338853 non-null  float64
#  458  PREV_NAME_TYPE_SUITE_Group of people_MEAN                              338853 non-null  float64
#  459  PREV_NAME_TYPE_SUITE_Other_A_MEAN                                      338853 non-null  float64
#  460  PREV_NAME_TYPE_SUITE_Other_B_MEAN                                      338853 non-null  float64
#  461  PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                              338853 non-null  float64
#  462  PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                338853 non-null  float64
#  463  PREV_NAME_TYPE_SUITE_nan_MEAN                                          338853 non-null  float64
#  464  PREV_NAME_CLIENT_TYPE_New_MEAN                                         338853 non-null  float64
#  465  PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                   338853 non-null  float64
#  466  PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                    338853 non-null  float64
# ...
#  642  INSTAL_PAYMENT_DIFF_MAX                                                339574 non-null  float64
#  643  INSTAL_PAYMENT_DIFF_MEAN                                               339574 non-null  float64
#  644  INSTAL_PAYMENT_DIFF_SUM                                                339583 non-null  float64
#  645  INSTAL_PAYMENT_DIFF_VAR                                                338606 non-null  float64
#  646  INSTAL_AMT_INSTALMENT_MAX                                              339583 non-null  float64
#  647  INSTAL_AMT_INSTALMENT_MEAN                                             339583 non-null  float64
#  648  INSTAL_AMT_INSTALMENT_SUM                                              339583 non-null  float64
#  649  INSTAL_AMT_PAYMENT_MIN                                                 339574 non-null  float64
#  650  INSTAL_AMT_PAYMENT_MAX                                                 339574 non-null  float64
#  651  INSTAL_AMT_PAYMENT_MEAN                                                339574 non-null  float64
#  652  INSTAL_AMT_PAYMENT_SUM                                                 339583 non-null  float64
#  653  INSTAL_DAYS_ENTRY_PAYMENT_MAX                                          339574 non-null  float64
#  654  INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                         339574 non-null  float64
#  655  INSTAL_DAYS_ENTRY_PAYMENT_SUM                                          339583 non-null  float64
#  656  INSTAL_COUNT                                                           339583 non-null  float64
#  657  CC_MONTHS_BALANCE_MIN                                                  103558 non-null  float64
#  658  CC_MONTHS_BALANCE_MAX                                                  103558 non-null  float64
#  659  CC_MONTHS_BALANCE_MEAN                                                 103558 non-null  float64
#  660  CC_MONTHS_BALANCE_SUM                                                  103558 non-null  float64
#  661  CC_MONTHS_BALANCE_VAR                                                  102866 non-null  float64
#  662  CC_AMT_BALANCE_MIN                                                     103558 non-null  float64
#  663  CC_AMT_BALANCE_MAX                                                     103558 non-null  float64
#  664  CC_AMT_BALANCE_MEAN                                                    103558 non-null  float64
#  665  CC_AMT_BALANCE_SUM                                                     103558 non-null  float64
#  666  CC_AMT_BALANCE_VAR                                                     102866 non-null  float64
#  667  CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                         103558 non-null  float64
#  668  CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                         103558 non-null  float64
#  669  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                        103558 non-null  float64
#  670  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                         103558 non-null  float64
#  671  CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                         102866 non-null  float64
#  672  CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                        72194 non-null   float64
#  673  CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                        72194 non-null   float64
#  674  CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                       72194 non-null   float64
#  675  CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                        103558 non-null  float64
#  676  CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                        71692 non-null   float64
#  677  CC_AMT_DRAWINGS_CURRENT_MIN                                            103558 non-null  float64
#  678  CC_AMT_DRAWINGS_CURRENT_MAX                                            103558 non-null  float64
#  679  CC_AMT_DRAWINGS_CURRENT_MEAN                                           103558 non-null  float64
#  680  CC_AMT_DRAWINGS_CURRENT_SUM                                            103558 non-null  float64
#  681  CC_AMT_DRAWINGS_CURRENT_VAR                                            102866 non-null  float64
#  682  CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                      72194 non-null   float64
#  683  CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                      72194 non-null   float64
#  684  CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                     72194 non-null   float64
#  685  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                      103558 non-null  float64
#  686  CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                      71692 non-null   float64
#  687  CC_AMT_DRAWINGS_POS_CURRENT_MIN                                        72194 non-null   float64
#  688  CC_AMT_DRAWINGS_POS_CURRENT_MAX                                        72194 non-null   float64
#  689  CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                       72194 non-null   float64
#  690  CC_AMT_DRAWINGS_POS_CURRENT_SUM                                        103558 non-null  float64
#  691  CC_AMT_DRAWINGS_POS_CURRENT_VAR                                        71692 non-null   float64
#  692  CC_AMT_INST_MIN_REGULARITY_MIN                                         103558 non-null  float64
#  693  CC_AMT_INST_MIN_REGULARITY_MAX                                         103558 non-null  float64
#  694  CC_AMT_INST_MIN_REGULARITY_MEAN                                        103558 non-null  float64
#  695  CC_AMT_INST_MIN_REGULARITY_SUM                                         103558 non-null  float64
#  696  CC_AMT_INST_MIN_REGULARITY_VAR                                         102866 non-null  float64
#  697  CC_AMT_PAYMENT_CURRENT_MIN                                             72120 non-null   float64
#  698  CC_AMT_PAYMENT_CURRENT_MAX                                             72120 non-null   float64
#  699  CC_AMT_PAYMENT_CURRENT_MEAN                                            72120 non-null   float64
#  700  CC_AMT_PAYMENT_CURRENT_SUM                                             103558 non-null  float64
#  701  CC_AMT_PAYMENT_CURRENT_VAR                                             71602 non-null   float64
#  702  CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                       103558 non-null  float64
#  703  CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                       103558 non-null  float64
#  704  CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                      103558 non-null  float64
#  705  CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                       103558 non-null  float64
#  706  CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                       102866 non-null  float64
#  707  CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                        103558 non-null  float64
#  708  CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                        103558 non-null  float64
#  709  CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                       103558 non-null  float64
#  710  CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                        103558 non-null  float64
#  711  CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                        102866 non-null  float64
#  712  CC_AMT_RECIVABLE_MIN                                                   103558 non-null  float64
#  713  CC_AMT_RECIVABLE_MAX                                                   103558 non-null  float64
#  714  CC_AMT_RECIVABLE_MEAN                                                  103558 non-null  float64
#  715  CC_AMT_RECIVABLE_SUM                                                   103558 non-null  float64
#  716  CC_AMT_RECIVABLE_VAR                                                   102866 non-null  float64
#  717  CC_AMT_TOTAL_RECEIVABLE_MIN                                            103558 non-null  float64
#  718  CC_AMT_TOTAL_RECEIVABLE_MAX                                            103558 non-null  float64
#  719  CC_AMT_TOTAL_RECEIVABLE_MEAN                                           103558 non-null  float64
#  720  CC_AMT_TOTAL_RECEIVABLE_SUM                                            103558 non-null  float64
#  721  CC_AMT_TOTAL_RECEIVABLE_VAR                                            102866 non-null  float64
#  722  CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                        72194 non-null   float64
#  723  CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                        72194 non-null   float64
#  724  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                       72194 non-null   float64
#  725  CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                        103558 non-null  float64
#  726  CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                        71692 non-null   float64
#  727  CC_CNT_DRAWINGS_CURRENT_MIN                                            103558 non-null  float64
#  728  CC_CNT_DRAWINGS_CURRENT_MAX                                            103558 non-null  float64
#  729  CC_CNT_DRAWINGS_CURRENT_MEAN                                           103558 non-null  float64
#  730  CC_CNT_DRAWINGS_CURRENT_SUM                                            103558 non-null  float64
#  731  CC_CNT_DRAWINGS_CURRENT_VAR                                            102866 non-null  float64
#  732  CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                      72194 non-null   float64
#  733  CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                      72194 non-null   float64
#  734  CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                     72194 non-null   float64
#  735  CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                      103558 non-null  float64
#  736  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                      71692 non-null   float64
#  737  CC_CNT_DRAWINGS_POS_CURRENT_MIN                                        72194 non-null   float64
#  738  CC_CNT_DRAWINGS_POS_CURRENT_MAX                                        72194 non-null   float64
#  739  CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                       72194 non-null   float64
#  740  CC_CNT_DRAWINGS_POS_CURRENT_SUM                                        103558 non-null  float64
#  741  CC_CNT_DRAWINGS_POS_CURRENT_VAR                                        71692 non-null   float64
#  742  CC_CNT_INSTALMENT_MATURE_CUM_MIN                                       103558 non-null  float64
#  743  CC_CNT_INSTALMENT_MATURE_CUM_MAX                                       103558 non-null  float64
#  744  CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                      103558 non-null  float64
#  745  CC_CNT_INSTALMENT_MATURE_CUM_SUM                                       103558 non-null  float64
#  746  CC_CNT_INSTALMENT_MATURE_CUM_VAR                                       102866 non-null  float64
#  747  CC_SK_DPD_MIN                                                          103558 non-null  float64
#  748  CC_SK_DPD_MAX                                                          103558 non-null  float64
#  749  CC_SK_DPD_MEAN                                                         103558 non-null  float64
#  750  CC_SK_DPD_SUM                                                          103558 non-null  float64
#  751  CC_SK_DPD_VAR                                                          102866 non-null  float64
#  752  CC_SK_DPD_DEF_MIN                                                      103558 non-null  float64
#  753  CC_SK_DPD_DEF_MAX                                                      103558 non-null  float64
#  754  CC_SK_DPD_DEF_MEAN                                                     103558 non-null  float64
#  755  CC_SK_DPD_DEF_SUM                                                      103558 non-null  float64
#  756  CC_SK_DPD_DEF_VAR                                                      102866 non-null  float64
#  757  CC_NAME_CONTRACT_STATUS_Active_MIN                                     103558 non-null  float64
#  758  CC_NAME_CONTRACT_STATUS_Active_MAX                                     103558 non-null  float64
#  759  CC_NAME_CONTRACT_STATUS_Active_MEAN                                    103558 non-null  float64
#  760  CC_NAME_CONTRACT_STATUS_Active_SUM                                     103558 non-null  float64
#  761  CC_NAME_CONTRACT_STATUS_Active_VAR                                     102866 non-null  float64
#  762  CC_NAME_CONTRACT_STATUS_Approved_MIN                                   103558 non-null  float64
#  763  CC_NAME_CONTRACT_STATUS_Approved_MAX                                   103558 non-null  float64
#  764  CC_NAME_CONTRACT_STATUS_Approved_MEAN                                  103558 non-null  float64
#  765  CC_NAME_CONTRACT_STATUS_Approved_SUM                                   103558 non-null  float64
#  766  CC_NAME_CONTRACT_STATUS_Approved_VAR                                   102866 non-null  float64
#  767  CC_NAME_CONTRACT_STATUS_Completed_MIN                                  103558 non-null  float64
#  768  CC_NAME_CONTRACT_STATUS_Completed_MAX                                  103558 non-null  float64
#  769  CC_NAME_CONTRACT_STATUS_Completed_MEAN                                 103558 non-null  float64
#  770  CC_NAME_CONTRACT_STATUS_Completed_SUM                                  103558 non-null  float64
#  771  CC_NAME_CONTRACT_STATUS_Completed_VAR                                  102866 non-null  float64
#  772  CC_NAME_CONTRACT_STATUS_Demand_MIN                                     103558 non-null  float64
#  773  CC_NAME_CONTRACT_STATUS_Demand_MAX                                     103558 non-null  float64
#  774  CC_NAME_CONTRACT_STATUS_Demand_MEAN                                    103558 non-null  float64
#  775  CC_NAME_CONTRACT_STATUS_Demand_SUM                                     103558 non-null  float64
#  776  CC_NAME_CONTRACT_STATUS_Demand_VAR                                     102866 non-null  float64
#  777  CC_NAME_CONTRACT_STATUS_Refused_MIN                                    103558 non-null  float64
#  778  CC_NAME_CONTRACT_STATUS_Refused_MAX                                    103558 non-null  float64
#  779  CC_NAME_CONTRACT_STATUS_Refused_MEAN                                   103558 non-null  float64
#  780  CC_NAME_CONTRACT_STATUS_Refused_SUM                                    103558 non-null  float64
#  781  CC_NAME_CONTRACT_STATUS_Refused_VAR                                    102866 non-null  float64
#  782  CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                              103558 non-null  float64
#  783  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                              103558 non-null  float64
#  784  CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                             103558 non-null  float64
#  785  CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                              103558 non-null  float64
#  786  CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                              102866 non-null  float64
#  787  CC_NAME_CONTRACT_STATUS_Signed_MIN                                     103558 non-null  float64
#  788  CC_NAME_CONTRACT_STATUS_Signed_MAX                                     103558 non-null  float64
#  789  CC_NAME_CONTRACT_STATUS_Signed_MEAN                                    103558 non-null  float64
#  790  CC_NAME_CONTRACT_STATUS_Signed_SUM                                     103558 non-null  float64
#  791  CC_NAME_CONTRACT_STATUS_Signed_VAR                                     102866 non-null  float64
#  792  CC_NAME_CONTRACT_STATUS_nan_MIN                                        103558 non-null  float64
#  793  CC_NAME_CONTRACT_STATUS_nan_MAX                                        103558 non-null  float64
#  794  CC_NAME_CONTRACT_STATUS_nan_MEAN                                       103558 non-null  float64
#  795  CC_NAME_CONTRACT_STATUS_nan_SUM                                        103558 non-null  float64
#  796  CC_NAME_CONTRACT_STATUS_nan_VAR                                        102866 non-null  float64
#  797  CC_COUNT                                                               103558 non-null  float64
# dtypes: float64(622), int64(43), uint8(133)
# memory usage: 1.8 GB

# %%
df = df[~df.TARGET.isna()]
#df.reset_index(inplace=True)

# %%
X = df.drop(columns=['TARGET','SK_ID_CURR','index'])
y = df['TARGET']

# %%
too_many_na = []
for col in X.columns:
    if (X[col].isnull().sum())/len(X)>0.5:
        too_many_na.append(col)
    mean_value = X[col].mean()
    X[col].fillna(value=mean_value, inplace=True)

# %%
X.drop(columns=too_many_na, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, roc_auc_score, f1_score

# %%
models = {
    'logistic':LogisticRegression(class_weight='balanced'),
    'randomforest':RandomForestClassifier(class_weight='balanced'),
}
#metrics = ['f1_', 'recall_', 'auc_']
res={}

# %%
def fit_and_predict(model, X_train, y_train, X_test):
    model.fit(X_train, y_train)
    return model.predict(X_test)

def f1_(y_test, predictions):
    return f1_score(y_test, predictions)
def recall_(y_test, predictions):
    return recall_score(y_test, predictions)
def auc_(y_test, predictions):
    return roc_auc_score(y_test, predictions)

# %%
# enleve les np.float.inf présente dans X
X.replace([np.inf, -np.inf], 0, inplace=True)

# %%
skf = StratifiedKFold(n_splits=3, random_state=123, shuffle=True)

for model_name, model in models.items():
    print(f'{model_name} beggining .........')
    
    res_f1=[]
    res_recall=[]
    res_auc= []
    
    # je fais un split stratifié
    for train_ix, test_ix in skf.split(X, y):
        X_train, X_test = X.iloc[train_ix], X.iloc[test_ix]
        y_train, y_test = y.iloc[train_ix], y.iloc[test_ix]
        predictions = fit_and_predict(model, X_train, y_train, X_test)
        res_f1.append(f1_(y_test, predictions))
        res_recall.append(recall_(y_test, predictions))
        res_auc.append(auc_(y_test, predictions))
    res[model_name] = {'f1':np.mean(res_f1),
                     'recall':np.mean(res_recall),
                     'auc':np.mean(res_auc)
                     }
    print(f'{model_name} endding .........')
# Out:
# logistic beggining .........
# /Users/maximedupouy/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/maximedupouy/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/maximedupouy/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic endding .........
# randomforest beggining .........
# randomforest endding .........

# %%
for key, value in res.items():
    print(key, value)
    print('')
# Out:
# logistic {'f1': 0.17616136726620799, 'recall': 0.3684592145015106, 'auc': 0.560806442468094}
#
# randomforest {'f1': 0.0014478474689609173, 'recall': 0.0007250755287009063, 'auc': 0.5003253935903752}
